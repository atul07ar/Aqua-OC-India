# %%
# ==========================================
# Lesson 28 - Earth Engine Machine Learning
# ==========================================

import ee
import geemap

ee.Initialize(project="oc-flux")

Map = geemap.Map()

point = ee.Geometry.Point([77.2090,28.6139])

collection = (
    ee.ImageCollection("LANDSAT/LC08/C02/T1_L2")
    .filterBounds(point)
    .filterDate("2023-01-01","2023-12-31")
)

image = collection.median()

Map.centerObject(point,10)

Map
# Out:
# Map(center=[28.613900000000005, 77.209], controls=(WidgetControl(options=['position', 'transparent_bg'], posit…

# %%
Machine Learning in Earth Engine

Unlike Scikit-learn,
Earth Engine performs machine learning on Google's servers.

Workflow:
Satellite Image

↓

Training Samples

↓

Earth Engine

↓

Random Forest

↓

Prediction

↓

Output Image

# %%
RandomForestRegressor()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 RandomForestRegressor()
#
# ...

# %%
Earth Engine Classifier

Earth Engine provides

# %%
ee.Classifier.smileRandomForest()
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 ee.Classifier.smileRandomForest()
#
# ...

# %%
Example:

# %%
classifier = ee.Classifier.smileRandomForest(
    numberOfTrees=100
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
Notice the similarity with

# %%
RandomForestClassifier(
    n_estimators=100
)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 RandomForestClassifier(
# ...

# %%
Earth Engine Regressor

Earth Engine also supports regression using the same Random Forest framework.

Example:
This changes the output from classes to continuous numerical values.

# %%
regressor = ee.Classifier.smileRandomForest(
    numberOfTrees=100
).setOutputMode("REGRESSION")
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>

# %%
Earth Engine FeatureCollection

Training samples are usually stored as:

# %%
ee.FeatureCollection()

# %%
Training the Model

Typical Earth Engine code:
Explanation

training → training dataset
classProperty → target variable
bands → predictor variables

# %%
classifier = ee.Classifier.smileRandomForest(
    numberOfTrees=100
)

trained = classifier.train(

    features=training,

    classProperty="class",

    inputProperties=bands

)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 7
#       3 )
#       4
# ...

# %%
Regression Example
Notice:

Instead of

class

we now use

POC

because POC is a continuous value.
For Aqua-OC:

# %%
regressor = ee.Classifier.smileRandomForest(
    numberOfTrees=200
).setOutputMode("REGRESSION")

# %%
Then:

# %%
trained = regressor.train(

    features=training,

    classProperty="POC",

    inputProperties=bands

)

# %%
Predictor Variables
These are exactly the features we created in previous lessons.
Example

# %%
bands = [

"SR_B2",

"SR_B3",

"SR_B4",

"SR_B5",

"NDWI",

"MNDWI"

]

# %%
Applying the Model
Even though the method is called .classify(), it also works for regression when the model has been set to "REGRESSION".
Diagram

Feature Stack

↓

Random Forest

↓

POC Image
After training:

# %%
prediction = feature_stack.classify(
    trained
)

# %%
Visualizing the Output
We can't execute this yet because we don't have real training data.

# %%
Map.addLayer(

prediction,

{

"min":0,

"max":10,

"palette":[

"blue",

"cyan",

"green",

"yellow",

"red"

]

},

"Predicted POC"

)

Map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 Map.addLayer(
#       2
# ...

# %%
Earth Engine Workflow
Satellite Image

↓

Training Samples

↓

Random Forest

↓

Prediction

↓

Map

# %%
Exercise 1

Create the predictor list.

# %%
bands = [

"SR_B2",

"SR_B3",

"SR_B4",

"SR_B5",

"NDWI",

"MNDWI"

]

print(bands)
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ['SR_B2', 'SR_B3', 'SR_B4', 'SR_B5', 'NDWI', 'MNDWI']

# %%
Exercise 2

Run
Confirm that every band in bands exists in your feature stack.

# %%
print(feature_stack.bandNames().getInfo())
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ...
