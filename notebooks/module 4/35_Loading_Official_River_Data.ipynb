# %%
# ==========================================
# Lesson 35
# Official River Data
# ==========================================

import ee
import geemap

ee.Initialize(project="oc-flux")

Map = geemap.Map()

Map
