# %%
Study Area Selection
          │
          ▼
Satellite Data Collection
          │
          ▼
Cloud Masking
          │
          ▼
Water Extraction
          │
          ▼
Feature Engineering
          │
          ▼
Training Dataset
          │
          ▼
Random Forest Model
          │
          ▼
POC Prediction
          │
          ▼
River Discharge
          │
          ▼
POC Flux
          │
          ▼
Statistical Analysis
          │
          ▼
Maps & Figures
          │
          ▼
Dissertation
