# %%
import os

print(os.getcwd())
# Out:
# C:\Users\Dell\Aqua_OC_India\notebooks\module 4

# %%
import os

for root, dirs, files in os.walk(os.getcwd()):
    for file in files:
        if "Cauvery" in file or "Ganga" in file:
            print(os.path.join(root, file))
# Out:
# C:\Users\Dell\Aqua_OC_India\notebooks\module 4\Cauvery_AquaOC_Final.ipynb
# C:\Users\Dell\Aqua_OC_India\notebooks\module 4\Cauvery_River_POC_Analysis.ipynb
# C:\Users\Dell\Aqua_OC_India\notebooks\module 4\Ganga_River_POC_Analysis (1).ipynb
# C:\Users\Dell\Aqua_OC_India\notebooks\module 4\Ganga_River_POC_Analysis_Final.ipynb
# C:\Users\Dell\Aqua_OC_India\notebooks\module 4\Lesson_41_Cauvery_Main_Stem_Extraction.ipynb
# C:\Users\Dell\Aqua_OC_India\notebooks\module 4\Lesson_41_Main_Cauvery_Extraction.ipynb
# C:\Users\Dell\Aqua_OC_India\notebooks\module 4\.ipynb_checkpoints\Cauvery_AquaOC_Final-checkpoint.ipynb
# C:\Users\Dell\Aqua_OC_India\notebooks\module 4\.ipynb_checkpoints\Cauvery_River_POC_Analysis-checkpoint.ipynb
# C:\Users\Dell\Aqua_OC_India\notebooks\module 4\.ipynb_checkpoints\Ganga_River_POC_Analysis (1)-checkpoint.ipynb
# C:\Users\Dell\Aqua_OC_India\notebooks\module 4\.ipynb_checkpoints\Ganga_River_POC_Analysis_Final-checkpoint.ipynb
# ...
