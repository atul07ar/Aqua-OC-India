# %%
import ee
import geemap

ee.Initialize(project="oc-flux")

Map = geemap.Map()

Map
# Out:
# Map(center=[0, 0], controls=(WidgetControl(options=['position', 'transparent_bg'], position='topright', transp…

# %%
import ee
import geemap

ee.Initialize(project="oc-flux")

Map = geemap.Map()

roi = ee.Geometry.Point([79.8033, 11.1313]).buffer(10000)

rivers = ee.FeatureCollection(
    "projects/oc-flux/assets/HydroRIVERS_v10_asi_shp"
)

cauvery = rivers.filterBounds(roi)

Map.centerObject(roi, 11)

Map.addLayer(cauvery, {"color": "blue"}, "Cauvery Rivers")

Map
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# Map(center=[11.131310258873006, 79.80330028994707], controls=(WidgetControl(options=['position', 'transparent_…

# %%
print(rivers.size().getInfo())
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# 1428959

# %%
print(rivers.first().getInfo())
# Out:
#             <style>
#                 .geemap-dark {
#                     --jp-widgets-color: white;
#                     --jp-widgets-label-color: white;
#                     --jp-ui-font-color1: white;
#                     --jp-layout-color2: #454545;
#                     background-color: #383838;
#                 }
#
#                 .geemap-dark .jupyter-button {
#                     --jp-layout-color3: #383838;
#                 }
#
#                 .geemap-colab {
#                     background-color: var(--colab-primary-surface-color, white);
#                 }
#
#                 .geemap-colab .jupyter-button {
#                     --jp-layout-color3: var(--colab-primary-surface-color, white);
#                 }
#             </style>
# {'type': 'Feature', 'geometry': {'type': 'LineString', 'coordinates': [[93.96875011316433, 22.545834741268784], [93.96875011316433, 22.56041600171356]]}, 'id': '0000000000000000780c', 'properties': {'CATCH_SKM': 5.35, 'DIST_DN_KM': 1224.8, 'DIST_UP_KM': 3.6, 'DIS_AV_CMS': 0.152, 'ENDORHEIC': 0, 'HYBAS_L12': 4120994010, 'HYRIV_ID': 41102109, 'LENGTH_KM': 1.62, 'MAIN_RIV': 41284417, 'NEXT_DOWN': 41101512, 'ORD_CLAS': 7, 'ORD_FLOW': 7, 'ORD_STRA': 1, 'UPLAND_SKM': 5.4}}
